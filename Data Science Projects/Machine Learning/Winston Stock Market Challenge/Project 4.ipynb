# %%
import turicreate as tc

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt

# %%
train_set = tc.SFrame('train.csv')
# Out:
# Finished parsing file /Users/afifmazhar/Desktop/Winston Stock Market Challenge/train.csv
# Parsing completed. Parsed 100 lines in 0.69574 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# ...

# %%
train_set.head()
# Out:
# Columns:
# 	Id	int
# 	Feature_1	float
# 	Feature_2	float
# 	Feature_3	float
# 	Feature_4	float
# 	Feature_5	float
# 	Feature_6	float
# 	Feature_7	int
# 	Feature_8	float
# 	Feature_9	float
# 	Feature_10	float
# 	Feature_11	float
# 	Feature_12	float
# 	Feature_13	float
# 	Feature_14	float
# 	Feature_15	float
# 	Feature_16	float
# 	Feature_17	float
# 	Feature_18	float
# 	Feature_19	float
# 	Feature_20	float
# 	Feature_21	float
# 	Feature_22	float
# 	Feature_23	float
# 	Feature_24	float
# 	Feature_25	float
# 	Ret_MinusTwo	float
# 	Ret_MinusOne	float
# 	Ret_2	float
# 	Ret_3	float
# 	Ret_4	float
# 	Ret_5	float
# 	Ret_6	float
# 	Ret_7	float
# 	Ret_8	float
# 	Ret_9	float
# 	Ret_10	float
# 	Ret_11	float
# 	Ret_12	float
# 	Ret_13	float
# 	Ret_14	float
# 	Ret_15	float
# 	Ret_16	float
# 	Ret_17	float
# 	Ret_18	float
# 	Ret_19	float
# 	Ret_20	float
# 	Ret_21	float
# 	Ret_22	float
# 	Ret_23	float
# 	Ret_24	float
# 	Ret_25	float
# 	Ret_26	float
# 	Ret_27	float
# 	Ret_28	float
# 	Ret_29	float
# ...

# %%
train_set.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of more than 50 columns will be suppressed.
# ...
